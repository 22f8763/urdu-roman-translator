# %%
# !python train.py
# Out:
# Total tensor pairs: 21003
# SplitOptions: Train=10501, Val=5250, Test=5252
# ✅ Created DataLoaders with batch_size=64
# ✅ Saved data_loaders_vocab.pth (optional)
#
# 🔍 Sanity check: One training batch
# Source batch shape: torch.Size([64, 85])
# Target batch shape: torch.Size([64, 102])
# Source lengths: tensor([26, 31, 33, 36, 40])
# Target lengths: tensor([37, 42, 46, 46, 50])
#
# 🎉 Phase 3 Complete! Ready for Model Architecture.
# Using device: cuda
# Train batches: 165, Val batches: 83
# Model parameters: 18,427,173
#
# 🧪 Testing model shapes...
# ✅ Shape test passed! Output shape: torch.Size([2, 6, 37])
#
# 🚀 Starting Training...
#
# ✅ Saved best model
# Epoch: 01 | Time: 0m 40s
# 	Train Loss: 2.644 | Train PPL:  14.076
# 	 Val Loss: 2.618 |  Val PPL:  13.702
# --------------------------------------------------
# ✅ Saved best model
# Epoch: 02 | Time: 0m 40s
# 	Train Loss: 2.214 | Train PPL:   9.156
# 	 Val Loss: 2.609 |  Val PPL:  13.582
# ...
